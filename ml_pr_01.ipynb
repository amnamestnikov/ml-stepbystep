# %% [markdown]
# <a href="https://colab.research.google.com/github/amnamestnikov/ml-stepbystep/blob/main/ml_pr_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Импорт необходимых библиотек

# %%
import numpy as np

# %% [markdown]
# Генерация данных:

# %%
true_b = 1
true_w = 2
N = 100

np.random.seed(42)
x = np.random.rand(N, 1)
epsilon = (0.1 * np.random.randn(N, 1))
y = true_b + true_w * x + epsilon

# %% [markdown]
# Визуализация сгенерированных данных

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y, color='red', marker='o')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
